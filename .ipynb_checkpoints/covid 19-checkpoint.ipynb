# %%
import pandas as pd
import numpy as np

# %%
# 사이트 변경 이전 데이터 크롤링 방법
# url = "http://seoul.go.kr/coronaV/coronaStatus.do
# table = pd.read_html(url)

# read_html 은 사이트 내의 html 태그를 불러옴
# table[0].T

# table 변수 안에 있는 table 태그의 값을 하나씩 읽어보며 확진자 목록이 있는 테이블을 가져옴
# df = table[4]

# last_day = df.loc[0, "확진일"]
# last_day = last_day.replace(".", "_")

#file_name = f"seoul-covid19_{last_day}.scv"

#df.to_csv(file_name, index=False)
#엑셀로 저장시 encoding='cp949'

#pd.read_csv(file_name)

# %% [markdown]
# ### 데이터 수집 방법
# 1. 수집하고자 하는 페이지의 URL을 알아본다.
# 2. 파이썬의 작은 브라우저 requests를 통해 URL에 접근한다.
# 3. response.status_code가 200 OK 라면 정상 응답입니다.
# 4. request의 response값에서 response.txt만 받아옵니다.
# 5. html 텍스트를 받아왔다면 bs(reponse.text, 'html.parser')로 html을 해석합니다.
# 6. soup.select를 통해 원하는 태그에 접근합니다.
# 7. 목록을 먼저 받아옵니다.
# 8. 목록에서 행을 하나씩 가져옵니다.
# 9. 행을 모아서 데이터프레임으로 만듭니다.

# %%
file_name = "seoul-covid19_6_30_.csv"
file_name
# Out:
# 'seoul-covid19_6_30_.csv'

# %%
df = pd.read_csv(file_name, encoding='utf-8')
df
# Out:
#         연번     환자    확진일   거주지     여행력          접촉력         조치사항
# 0     1321  12830  6.30.  영등포구       -  영등포구 확진자 접촉            -
# 1     1320  12829  6.30.   관악구       -         확인 중        보라매병원
# 2     1319  12831  6.30.  영등포구       -         확인 중      중앙대학교병원
# 3     1318  12808  6.30.   관악구       -   강남구 역삼동 모임        보라매병원
# 4     1317  12809  6.30.   관악구       -   강남구 역삼동 모임        보라매병원
# ...    ...    ...    ...   ...     ...          ...          ...
# 1316     5      9  1.31.   성북구       -        #5 접촉    서울의료원(퇴원)
# 1317     4      7  1.30.   마포구  중국 우한시        해외 접촉    서울의료원(퇴원)
# 1318     3      6  1.30.   종로구       -        #3 접촉  서울대학교병원(퇴원)
# 1319     2      5  1.30.   중랑구  중국 우한시        해외 접촉    서울의료원(퇴원)
# 1320     1      2  1.24.   강서구  중국 우한시        해외 접촉  국립중앙의료원(퇴원)
#
# [1321 rows x 7 columns]

# %%
df.shape
# Out:
# (1321, 7)

# %%
df.head()
# Out:
#      연번     환자    확진일   거주지 여행력          접촉력     조치사항
# 0  1321  12830  6.30.  영등포구   -  영등포구 확진자 접촉        -
# 1  1320  12829  6.30.   관악구   -         확인 중    보라매병원
# 2  1319  12831  6.30.  영등포구   -         확인 중  중앙대학교병원
# 3  1318  12808  6.30.   관악구   -   강남구 역삼동 모임    보라매병원
# 4  1317  12809  6.30.   관악구   -   강남구 역삼동 모임    보라매병원

# %%
last_day = df.loc[0, '확진일']
last_day = last_day.replace('.', '_')
last_day
# Out:
# '6_30_'

# %%
file_name = f"seoul-covid19_{last_day}.csv"
file_name
# Out:
# 'seoul-covid19_6_30_.csv'

# %%
# csv 파일로 저장
# df.to_csv(file_name, index=False, encoding='cp949')
# cp949는 엑셀용

# %%
df = df.sort_values(by="연번", ascending=False)

# %%
df.head()
# Out:
#      연번     환자    확진일   거주지 여행력          접촉력     조치사항
# 0  1321  12830  6.30.  영등포구   -  영등포구 확진자 접촉        -
# 1  1320  12829  6.30.   관악구   -         확인 중    보라매병원
# 2  1319  12831  6.30.  영등포구   -         확인 중  중앙대학교병원
# 3  1318  12808  6.30.   관악구   -   강남구 역삼동 모임    보라매병원
# 4  1317  12809  6.30.   관악구   -   강남구 역삼동 모임    보라매병원

# %%
import matplotlib.pyplot as plt
# 한글 폰트
plt.rc("font", family='Malgun Gothic')
# 마이너스 기호
plt.rc("axes", unicode_minus=False)
# 스타일
plt.style.use('fivethirtyeight')

pd.Series([1,3,5,-7,9]).plot.bar(title="한글 제목")
# Out:
# <AxesSubplot:title={'center':'한글 제목'}>

# %%
# 레티나 해상도 적용
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %% [markdown]
# # 3 확진일

# %%
df["확진일"].value_counts()
# Out:
# 3.10.    46
# 6.12.    30
# 6.06.    29
# 6.05.    27
# 3.9.     26
#          ..
# 5.17.     1
# 4.19.     1
# 2.2.      1
# 5.31.     1
# 2.7.      1
# Name: 확진일, Length: 131, dtype: int64

# %%
df['확진일자'] = pd.to_datetime("2020-" + df['확진일'].str.replace(".", "-"))
df[['확진일', '확진일자']].head()
# Out:
#      확진일       확진일자
# 0  6.30. 2020-06-30
# 1  6.30. 2020-06-30
# 2  6.30. 2020-06-30
# 3  6.30. 2020-06-30
# 4  6.30. 2020-06-30

# %%
# 월 추출
df['월'] = df['확진일자'].dt.month
df[['확진일', '확진일자', '월']].tail()
# Out:
#         확진일       확진일자  월
# 1316  1.31. 2020-01-31  1
# 1317  1.30. 2020-01-30  1
# 1318  1.30. 2020-01-30  1
# 1319  1.30. 2020-01-30  1
# 1320  1.24. 2020-01-24  1

# %%
# 주 추출
df['주'] = df['확진일자'].dt.week
df[['확진일', '확진일자', '월', '주']].head()
# Out:
# <ipython-input-16-3e340815c247>:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['주'] = df['확진일자'].dt.week
#      확진일       확진일자  월   주
# 0  6.30. 2020-06-30  6  27
# 1  6.30. 2020-06-30  6  27
# 2  6.30. 2020-06-30  6  27
# 3  6.30. 2020-06-30  6  27
# 4  6.30. 2020-06-30  6  27

# %% [markdown]
# ## 3.1 선그래프 그리기

# %%
df['확진일자'].value_counts().plot(figsize=(15, 4))
plt.axhline(30, color='red', linestyle=':')

# %%
df['월'].value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
df['월일'] = df['확진일자'].astype(str).map(lambda x : x[-5:])
day_count = df['월일'].value_counts().sort_index()
day_count.iloc[0]
# Out:
# 1

# %%
for i in range(len(day_count)):
    print(i, day_count.iloc[i])
# Out:
# 0 1
# 1 3
# 2 3
# 3 1
# 4 2
# 5 1
# 6 1
# 7 2
# 8 2
# 9 5
# 10 2
# 11 4
# 12 4
# 13 4
# 14 16
# 15 10
# 16 13
# 17 8
# 18 5
# 19 6
# 20 6
# 21 1
# 22 5
# 23 1
# 24 7
# 25 7
# 26 10
# 27 26
# 28 46
# 29 17
# 30 12
# 31 9
# 32 8
# 33 6
# 34 13
# 35 4
# 36 11
# 37 17
# 38 17
# 39 8
# 40 6
# 41 5
# 42 14
# 43 13
# 44 14
# 45 15
# 46 22
# 47 22
# 48 19
# 49 24
# 50 16
# 51 19
# 52 20
# 53 19
# 54 11
# 55 8
# 56 10
# 57 11
# 58 5
# 59 3
# 60 2
# 61 8
# 62 3
# 63 5
# 64 1
# 65 2
# 66 2
# 67 1
# 68 1
# 69 1
# 70 2
# 71 1
# 72 4
# 73 1
# 74 1
# 75 2
# 76 13
# 77 18
# 78 20
# 79 12
# 80 8
# 81 5
# 82 12
# 83 6
# 84 4
# 85 1
# 86 7
# 87 9
# 88 4
# 89 3
# 90 3
# 91 6
# 92 7
# 93 8
# 94 19
# 95 25
# 96 19
# 97 9
# 98 6
# 99 1
# 100 14
# 101 20
# 102 14
# 103 15
# 104 27
# 105 29
# 106 15
# 107 18
# 108 14
# 109 19
# 110 25
# 111 30
# 112 12
# 113 7
# 114 11
# 115 14
# 116 24
# 117 18
# 118 16
# 119 15
# 120 8
# 121 4
# 122 10
# 123 9
# 124 17
# 125 17
# 126 14
# 127 7
# 128 8
# 129 8

# %%
g = day_count.plot(figsize=(15,4))
for i in range(len(day_count)):
    case_count = day_count.iloc[i]
    if case_count > 20:
        g.text(x=i, y=case_count, s=case_count)

# %% [markdown]
# ## 3.3 확진자가 가장 많이 나온 날

# %%
day_count.describe()
# Out:
# count    130.000000
# mean      10.161538
# std        7.917015
# min        1.000000
# 25%        4.000000
# 50%        8.000000
# 75%       15.000000
# max       46.000000
# Name: 월일, dtype: float64

# %%
day_count[day_count == day_count.max()]
# Out:
# 03-10    46
# Name: 월일, dtype: int64

# %%
df[df["월일"] == "03-10"]
# Out:
#        연번    환자    확진일   거주지       여행력           접촉력         조치사항       확진일자  \
# 1119  202  7567  3.10.   노원구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1120  201  7711  3.10.   노원구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1121  200  7555  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1122  199  7725  3.10.   양천구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1123  198  7539  3.10.   양천구         -      콜센터직원 접촉     서남병원(퇴원) 2020-03-10
# 1124  197  7524  3.10.   양천구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1125  196  7619  3.10.   양천구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1126  195  7795  3.10.   관악구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1127  194  7787  3.10.   관악구         -      콜센터직원 접촉     서남병원(퇴원) 2020-03-10
# 1128  193  7826  3.10.   관악구         -      콜센터직원 접촉     서남병원(퇴원) 2020-03-10
# 1129  192  7800  3.10.   관악구         -      콜센터직원 접촉    서울의료원(퇴원) 2020-03-10
# 1130  191  7647  3.10.   은평구  프랑스, 스페인  #6959 접촉(추정)     서북병원(퇴원) 2020-03-10
# 1131  190  7588  3.10.   마포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1132  189  7536  3.10.  동대문구         -       동대문구 관련  국립중앙의료원(퇴원) 2020-03-10
# 1133  188  7561  3.10.  동대문구         -  #7280 접촉(추정)  국립중앙의료원(퇴원) 2020-03-10
# 1134  187  7637  3.10.   금천구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1135  186  7630  3.10.  영등포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1136  185  7742  3.10.   마포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1137  184  7823  3.10.   마포구         -    구로구 콜센터 관련  서울대학교병원(퇴원) 2020-03-10
# 1138  183  7840  3.10.   마포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1139  182  7611  3.10.   동작구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1140  181  7528  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1141  180  7520  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1142  179  7584  3.10.   구로구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1143  178  7602  3.10.  동대문구         -       동대문구 관련    서울의료원(퇴원) 2020-03-10
# 1144  177  7523  3.10.   구로구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1145  176  7564  3.10.  영등포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1146  175  7695  3.10.   강서구         -    구로구 콜센터 관련     서북병원(퇴원) 2020-03-10
# 1147  174  7571  3.10.  동대문구         -       동대문구 관련    서울의료원(퇴원) 2020-03-10
# 1148  173  7731  3.10.   강서구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1149  172  7642  3.10.   양천구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1150  171  7638  3.10.   양천구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1151  170  7734  3.10.   관악구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1152  169  7712  3.10.   양천구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1153  168  7653  3.10.  영등포구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1154  167  7622  3.10.  영등포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1155  166  7685  3.10.  영등포구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1156  165  7624  3.10.   송파구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1157  164  7573  3.10.   은평구         -  #7500 접촉(추정)    서울의료원(퇴원) 2020-03-10
# 1158  163  7723  3.10.   강서구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1159  162  7727  3.10.   강서구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1160  161  7603  3.10.   관악구         -    구로구 콜센터 관련    보라매병원(퇴원) 2020-03-10
# 1161  160  7644  3.10.   관악구         -    구로구 콜센터 관련    보라매병원(퇴원) 2020-03-10
# 1162  159  7666  3.10.   관악구         -    구로구 콜센터 관련    서울의료원(퇴원) 2020-03-10
# 1163  158  7721  3.10.   동작구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
# 1164  157  7525  3.10.   동작구         -    구로구 콜센터 관련     서남병원(퇴원) 2020-03-10
#
#       월   주     월일
# 1119  3  11  03-10
# 1120  3  11  03-10
# 1121  3  11  03-10
# 1122  3  11  03-10
# 1123  3  11  03-10
# 1124  3  11  03-10
# 1125  3  11  03-10
# 1126  3  11  03-10
# 1127  3  11  03-10
# 1128  3  11  03-10
# 1129  3  11  03-10
# 1130  3  11  03-10
# 1131  3  11  03-10
# 1132  3  11  03-10
# 1133  3  11  03-10
# 1134  3  11  03-10
# 1135  3  11  03-10
# 1136  3  11  03-10
# 1137  3  11  03-10
# 1138  3  11  03-10
# 1139  3  11  03-10
# 1140  3  11  03-10
# 1141  3  11  03-10
# 1142  3  11  03-10
# 1143  3  11  03-10
# 1144  3  11  03-10
# 1145  3  11  03-10
# 1146  3  11  03-10
# 1147  3  11  03-10
# 1148  3  11  03-10
# 1149  3  11  03-10
# 1150  3  11  03-10
# 1151  3  11  03-10
# 1152  3  11  03-10
# 1153  3  11  03-10
# 1154  3  11  03-10
# 1155  3  11  03-10
# 1156  3  11  03-10
# 1157  3  11  03-10
# 1158  3  11  03-10
# 1159  3  11  03-10
# 1160  3  11  03-10
# 1161  3  11  03-10
# 1162  3  11  03-10
# 1163  3  11  03-10
# 1164  3  11  03-10

# %%
day_count.plot.bar(figsize=(30,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3.5 최근 데이터만 슬라이싱으로 나눠 그리기

# %%
g = day_count[-50:].plot.bar(figsize=(15,4))
g.axhline(day_count.median(), linestyle=":", color="red")
for i in range(50):
    case_count = day_count[-50:].iloc[i]
    if case_count > 10:
        g.text(x=i-0.5, y=case_count, s=case_count)

# %%
changing check
